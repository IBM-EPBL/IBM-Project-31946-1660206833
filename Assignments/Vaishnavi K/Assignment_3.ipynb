# %% [markdown]
# # Assignment_3

# %% [markdown]
# # IMAGE AUGMENTATION

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
xtrain = train_datagen.flow_from_directory('C:\\Users\\vaishu\\Downloads\\Flowers-Dataset\\flowers',
                                           target_size=(64,64),
                                           class_mode='categorical',
                                           batch_size=100)
# Out:
# Found 4317 images belonging to 5 classes.

# %% [markdown]
# # CREAT MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D,MaxPooling2D,Flatten,Dense

# %% [markdown]
# # ADD LAYERS

# %%
model = Sequential()
model.add(Convolution2D(32,(3,3),activation='relu',input_shape=(64,64,3))) # Convolution layer
model.add(MaxPooling2D(pool_size=(2,2))) # Max pooling layer
model.add(Flatten()) # Flatten layer
# Dense layers
model.add(Dense(300,activation='relu')) # Hidden layer
model.add(Dense(150,activation='relu')) # Hidden layer
model.add(Dense(5,activation='softmax')) # Output layer

# %% [markdown]
# # COMPILE THE MODEL

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# # FIT THE MODEL

# %%
model.fit(xtrain,
          steps_per_epoch=len(xtrain),
          epochs=10,
          )
# Out:
# Epoch 1/10
# 44/44 [==============================] - 98s 2s/step - loss: 1.6025 - accuracy: 0.3651
# Epoch 2/10
# 44/44 [==============================] - 71s 2s/step - loss: 1.1047 - accuracy: 0.5562
# Epoch 3/10
# 44/44 [==============================] - 64s 1s/step - loss: 1.0076 - accuracy: 0.5993
# Epoch 4/10
# 44/44 [==============================] - 33s 743ms/step - loss: 0.9596 - accuracy: 0.6266
# Epoch 5/10
# 44/44 [==============================] - 33s 726ms/step - loss: 0.8780 - accuracy: 0.6648
# Epoch 6/10
# 44/44 [==============================] - 32s 719ms/step - loss: 0.8197 - accuracy: 0.6861
# Epoch 7/10
# 44/44 [==============================] - 30s 675ms/step - loss: 0.8001 - accuracy: 0.6956
# Epoch 8/10
# 44/44 [==============================] - 31s 704ms/step - loss: 0.7433 - accuracy: 0.7174
# Epoch 9/10
# 44/44 [==============================] - 30s 671ms/step - loss: 0.7098 - accuracy: 0.7336
# Epoch 10/10
# ...

# %% [markdown]
# # SAVE THE MODEL

# %%
model.save('flowers.h5')

# %% [markdown]
# # TESTING THE MODEL

# %%
import numpy as np

# %%
from tensorflow.keras.preprocessing import image

# %%
img = image.load_img('C:\\Users\\vaishu\\Downloads\\Flowers-Dataset\\flowers\\sunflower\\9206376642_8348ba5c7a.jpg',target_size=(64,64))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x2491845C6A0>

# %%
x = image.img_to_array(img)
x
x = np.expand_dims(x,axis=0)
x
model.predict(x)
# Out:
# 1/1 [==============================] - 0s 115ms/step
# array([[0., 0., 0., 1., 0.]], dtype=float32)

# %%
xtrain.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
op = ['daisy','dandelion','rose','sunflower','tulip']
pred = np.argmax(model.predict(x))
op[pred]
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 'sunflower'

# %% [markdown]
# # Daisy Testing

# %%
from numpy.lib.type_check import imag

# %%
img = image.load_img('C:\\Users\\vaishu\\Downloads\\Flowers-Dataset\\flowers\\daisy\\107592979_aaa9cdfe78_m.jpg',target_size=(64,64))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x24918457910>

# %%
x = image.img_to_array(img)

# %%
x = np.expand_dims(x,axis=0)

# %%
pred = np.argmax(model.predict(x))
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
op[pred]
# Out:
# 'daisy'

# %% [markdown]
# # Dandelion Testing

# %%
img = image.load_img('C:\\Users\\vaishu\\Downloads\\Flowers-Dataset\\flowers\\dandelion\\141935731_d26d600f4f_m.jpg',target_size=(64,64))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x24919361220>

# %%
x = image.img_to_array(img)

# %%
x = np.expand_dims(x,axis=0)

# %%
pred = np.argmax(model.predict(x))
op[pred]
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 'dandelion'

# %% [markdown]
# # Rose Testing

# %%
img = image.load_img('C:\\Users\\vaishu\\Downloads\\Flowers-Dataset\\flowers\\rose\\1775233884_12ff5a124f.jpg',target_size=(64,64))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x249195FA9A0>

# %%
x = image.img_to_array(img)

# %%
x = np.expand_dims(x,axis=0)

# %%
pred = np.argmax(model.predict(x))
op[pred]
# Out:
# 1/1 [==============================] - 0s 38ms/step
# 'rose'

# %% [markdown]
# # Tulip Testing

# %%
img = image.load_img('C:\\Users\\vaishu\\Downloads\\Flowers-Dataset\\flowers\\tulip\\17094167287_865840060d_n.jpg',target_size=(64,64))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x249193DFEB0>

# %%
x = image.img_to_array(img)

# %%
x = np.expand_dims(x,axis=0)

# %%
pred = np.argmax(model.predict(x))
op[pred]
# Out:
# 1/1 [==============================] - 0s 38ms/step
# 'tulip'

# %% [markdown]
# # Rose

# %%
img = image.load_img('C:\\Users\\vaishu\\Downloads\\Flowers-Dataset\\flowers\\rose\\118974357_0faa23cce9_n.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x241 at 0x24919600F40>

# %%
x=image.img_to_array(img)
x
# Out:
# array([[[ 26.,  42.,   3.],
#         [ 32.,  48.,   9.],
#         [ 36.,  51.,  12.],
#         ...,
#         [ 61.,  61.,  37.],
#         [ 66.,  67.,  36.],
#         [ 84.,  84.,  50.]],
#
#        [[ 28.,  44.,   5.],
#         [ 32.,  48.,   9.],
#         [ 35.,  50.,  11.],
#         ...,
#         [ 59.,  58.,  37.],
#         [ 66.,  66.,  38.],
#         [ 85.,  86.,  52.]],
#
#        [[ 33.,  49.,  10.],
#         [ 36.,  51.,  12.],
#         [ 36.,  51.,  10.],
#         ...,
#         [ 58.,  57.,  36.],
#         [ 69.,  69.,  43.],
#         [ 86.,  87.,  55.]],
#
#        ...,
#
#        [[106.,  74.,  15.],
#         [ 57.,  34.,   0.],
#         [ 58.,  42.,   8.],
#         ...,
#         [ 30.,  10.,   1.],
#         [ 39.,  22.,   6.],
#         [ 32.,  16.,   1.]],
#
#        [[118.,  83.,  19.],
#         [ 57.,  36.,   0.],
#         [ 54.,  45.,   6.],
#         ...,
#         [ 40.,  18.,   5.],
#         [ 41.,  21.,  10.],
# ...
