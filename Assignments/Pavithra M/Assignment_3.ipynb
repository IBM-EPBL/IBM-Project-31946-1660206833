# %% [markdown]
# # Assignment 3

# %% [markdown]
# # IMAGE AUGMENTATION

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
xtrain = train_datagen.flow_from_directory('C:\\Users\\pavi\\Desktop\\Flowers-Dataset\\flowers',
                                           target_size=(64,64),
                                           class_mode='categorical',
                                           batch_size=100)
# Out:
# Found 4317 images belonging to 5 classes.

# %% [markdown]
# # CREAT MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D,MaxPooling2D,Flatten,Dense

# %% [markdown]
# # ADD LAYERS

# %%
model = Sequential()
model.add(Convolution2D(32,(3,3),activation='relu',input_shape=(64,64,3))) # Convolution layer
model.add(MaxPooling2D(pool_size=(2,2))) # Max pooling layer
model.add(Flatten()) # Flatten layer
# Dense layers
model.add(Dense(300,activation='relu')) # Hidden layer
model.add(Dense(150,activation='relu')) # Hidden layer
model.add(Dense(5,activation='softmax')) # Output layer

# %% [markdown]
# # COMPILE THE MODEL

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# # FIT THE MODEL

# %%
model.fit(xtrain,
          steps_per_epoch=len(xtrain),
          epochs=10,
          )
# Out:
# Epoch 1/10
# 44/44 [==============================] - 47s 1s/step - loss: 1.8284 - accuracy: 0.3521
# Epoch 2/10
# 44/44 [==============================] - 45s 1s/step - loss: 1.1672 - accuracy: 0.5180
# Epoch 3/10
# 44/44 [==============================] - 45s 1s/step - loss: 1.0737 - accuracy: 0.5691
# Epoch 4/10
# 44/44 [==============================] - 45s 1s/step - loss: 1.0129 - accuracy: 0.6053
# Epoch 5/10
# 44/44 [==============================] - 45s 1s/step - loss: 0.9441 - accuracy: 0.6375
# Epoch 6/10
# 44/44 [==============================] - 45s 1s/step - loss: 0.9310 - accuracy: 0.6379
# Epoch 7/10
# 44/44 [==============================] - 48s 1s/step - loss: 0.8662 - accuracy: 0.6699
# Epoch 8/10
# 44/44 [==============================] - 46s 1s/step - loss: 0.8369 - accuracy: 0.6820
# Epoch 9/10
# 44/44 [==============================] - 45s 1s/step - loss: 0.7763 - accuracy: 0.7139
# Epoch 10/10
# ...

# %% [markdown]
# # SAVE THE MODEL

# %%
model.save('flowers.h5')

# %% [markdown]
# # TEST THE MODEL

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
img = image.load_img('C:\\Users\\pavi\\Desktop\\Flowers-Dataset\\flowers\\sunflower\\9206376642_8348ba5c7a.jpg',target_size=(64,64))
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x23516644C70>

# %%
x = image.img_to_array(img)
x
x = np.expand_dims(x,axis=0)
x
model.predict(x)
# Out:
# 1/1 [==============================] - 0s 243ms/step
# array([[0., 0., 0., 1., 0.]], dtype=float32)

# %%
xtrain.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
op = ['daisy','dandelion','rose','sunflower','tulip']
pred = np.argmax(model.predict(x))
op[pred]
# Out:
# 1/1 [==============================] - 0s 62ms/step
# 'sunflower'

# %% [markdown]
# # DAISY TESTING

# %%
from numpy.lib.type_check import imag
img = image.load_img('C:\\Users\\pavi\\Desktop\\Flowers-Dataset\\flowers\\daisy\\413815348_764ae83088.jpg',target_size=(64,64))
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x2351D2E7970>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
pred = np.argmax(model.predict(x))
op[pred]
# Out:
# 1/1 [==============================] - 0s 42ms/step
# 'daisy'

# %% [markdown]
# # Tulip Testing

# %%
img = image.load_img('C:\\Users\\pavi\\Desktop\\Flowers-Dataset\\flowers\\tulip\\3539077354_c67aa7168d_m.jpg',target_size=(64,64))
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x2351D2DAE20>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
pred = np.argmax(model.predict(x))
op[pred]
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 'tulip'

# %% [markdown]
# # Rose Testing

# %%
img = image.load_img('C:\\Users\\pavi\\Desktop\\Flowers-Dataset\\flowers\\rose\\3997609936_8db20b7141_n.jpg',target_size=(64,64))
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x2351E266B20>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
pred = np.argmax(model.predict(x))
op[pred]
# Out:
# 1/1 [==============================] - 0s 60ms/step
# 'rose'

# %% [markdown]
# # Sunflower Testing

# %%
img = image.load_img('C:\\Users\\pavi\\Desktop\\Flowers-Dataset\\flowers\\sunflower\\4560663938_3557a1f831.jpg',target_size=(64,64))
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x2351E256D60>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
pred = np.argmax(model.predict(x))
op[pred]
# Out:
# 1/1 [==============================] - 0s 59ms/step
# 'sunflower'

# %% [markdown]
# # Tulip

# %%
img = image.load_img('C:\\Users\\pavi\\Desktop\\Flowers-Dataset\\flowers\\tulip\\112650879_82adc2cc04_n.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x229 at 0x2351E31EBE0>
