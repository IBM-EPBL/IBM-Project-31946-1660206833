# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
model=load_model('fruits.h5')

# %%
img=image.load_img(r"corn healthy.jpg",target_size=(128,128))
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1AE1F9B39D0>

# %%
import numpy as np

# %%
x = image.img_to_array(img)

# %%
x = np.expand_dims(x,axis=0)

# %%
x.shape
# Out:
# (1, 128, 128, 3)

# %%
pred=np.argmax(model.predict(x),axis=1)
# Out:
# 1/1 [==============================] - 0s 81ms/step

# %%
pred[0]
# Out:
# 4

# %%
index=['Apple___Black_rot','Corn_(maize)___healthy','Corn_(maize)___Northern_Leaf_Blight','Apple___healthy','Peach___Bacterial_spot','Peach___healthy']

# %%
a=index[pred[0]-3]
print(a)
# Out:
# Corn_(maize)___healthy
